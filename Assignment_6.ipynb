# %% [markdown]
# # Assignment - 6

# %% [markdown]
# 1.What are escape characters, and how do you use them?

# %% [markdown]
# Ans : Escape characters represent characters in string values that would otherwise be difficult or impossible to type into code. we can use the backslash character to escape a single character or symbol
#
# Ex : \t , \n

# %% [markdown]
# 2.What do the escape characters n and t stand for?

# %% [markdown]
# Ans : \n is a newline, \t is a tab

# %% [markdown]
# 3.What is the way to include backslash characters in a string?

# %% [markdown]
# Ans : The \\ escape character will represent the backslash character in a string

# %% [markdown]
# 4.The string &quot;Howl&#39;s Moving Castle&quot; is a correct value. Why isn&#39;t the single quote character in the
# word Howl&#39;s not escaped a problem?

# %% [markdown]
# Ans : The string "Howl's Moving Castle" escape the problem because it is wrapped inside double quotes. if its wrapped inside single quotes then we have to use escape character '\' to show single quote in the final output
# 'Howl\'s Moving Castle -> 'Howl's Moving Castle'

# %% [markdown]
# 5.How do you write a string of newlines if you don&#39;t want to use the n character?

# %% [markdown]
# Multiline string allow you to use newlines in string without the \n escape character

# %%
a = '''Samir Saiyed
Data Scientist'''
print(a)
# Out:
# Samir Saiyed
# Data Scientist

# %% [markdown]
# 6.What are the values of the given expressions?
#
# &#39;Hello, world!&#39;[1]
# &#39;Hello, world!&#39;[0:5]
# &#39;Hello, world!&#39;[:5]
# &#39;Hello, world!&#39;[3:]

# %% [markdown]
# Ans : The values for the given expressions are:
# 'Hello, world!'[1] -> 'e'
# 'Hello, world!'[0:5] -> 'Hello'
# 'Hello, world!'[:5] -> 'Hello'
# 'Hello, world!'[3:] -> 'lo, world!'

# %% [markdown]
# 7.What are the values of the following expressions?
#
# &#39;Hello&#39;.upper()
# &#39;Hello&#39;.upper().isupper()
# &#39;Hello&#39;.upper().lower()

# %% [markdown]
# Ans :
# 'Hello'.upper() -> 'HELLO'
# 'Hello'.upper().isupper() -> True
# 'Hello'.upper().lower() -> 'hello'

# %% [markdown]
# 8.What are the values of the following expressions?
#
# &#39;Remember, remember, the fifth of July.&#39;.split()
# &#39;-&#39;.join(&#39;There can only one.&#39;.split())

# %% [markdown]
# Ans : The vlaues for the given expression are :
#
# 'Remember,remember,the fifth of July.'.split() -> ['Remember,','rememember,','the','fifth','of', 'July.']
# '-'.join('There can only one.'.split()) -> 'There-can-inly-one

# %% [markdown]
# 9.What are the methods for right-justifying, left-justifying, and centering a string?

# %% [markdown]
# Ans : The rjust(),ljust(),center() string methods , respectively

# %% [markdown]
# 10.What is the best way to remove whitespace characters from the start or end?

# %% [markdown]
# Ans : The lstrip() and rstrip() methods remove whitespace characters from the left and right ends of a string respectively.
